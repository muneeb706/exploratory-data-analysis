# %%
import pandas as pd
import numpy as np

pd.set_option("display.precision", 2)

# %%
data = pd.read_csv("msa_naicssector_2016.csv")
data.sample(5)
# Out:
#        FIPS    CODE             MSA DESCRIPTION NAICS   CODE   \
# 48412         22820  Fort Morgan, CO Micro Area            51
# 86952         32900       Merced, CA Metro Area            52
# 35505         19540      Decatur, IN Micro Area            23
# 52266         24020  Glens Falls, NY Metro Area            23
# 57754         25460     Harrison, AR Micro Area            52
#
#            NAICS DESCRIPTION ENTERPRISE EMPLOYMENT SIZE NUMBER OF FIRMS  \
# 48412            Information                   02:  0-4               2
# 86952  Finance and Insurance                   05:  <20              66
# 35505           Construction                 04:  10-19               7
# 52266           Construction                  08:  <500             348
# 57754  Finance and Insurance                  09:  500+               6
#
#       NUMBER OF ESTABLISHMENTS EMPLOYMENT EMPLOYMENT RANGE FLAG  \
# 48412                        2          0                     A
# ...

# %%
print(data.shape)
# Out:
# (149790, 12)

# %%
print(data.columns)
# Out:
# Index(['FIPS    CODE', 'MSA DESCRIPTION', 'NAICS   CODE ', 'NAICS DESCRIPTION',
#        'ENTERPRISE EMPLOYMENT SIZE', 'NUMBER OF FIRMS',
#        'NUMBER OF ESTABLISHMENTS', 'EMPLOYMENT', 'EMPLOYMENT RANGE FLAG',
#        'EMPLOYMENT NOISE FLAG', 'ANNUAL PAYROLL ($1,000)',
#        'ANNUAL PAYROLL NOISE FLAG'],
#       dtype='object')

# %%
print(data.info)
# Out:
# <bound method DataFrame.info of         FIPS    CODE          MSA DESCRIPTION NAICS   CODE   \
# 0              10100  Aberdeen, SD Micro Area            --
# 1              10100  Aberdeen, SD Micro Area            --
# 2              10100  Aberdeen, SD Micro Area            --
# 3              10100  Aberdeen, SD Micro Area            --
# 4              10100  Aberdeen, SD Micro Area            --
# ...              ...                      ...           ...
# 149785         49820    Zapata, TX Micro Area            81
# 149786         49820    Zapata, TX Micro Area            81
# 149787         49820    Zapata, TX Micro Area            81
# 149788         49820    Zapata, TX Micro Area            81
# 149789         49820    Zapata, TX Micro Area            81
#
#                                     NAICS DESCRIPTION  \
# 0                                               Total
# 1                                               Total
# ...

# %%
data.describe(include=['object'])
# Out:
#                                          MSA DESCRIPTION NAICS   CODE   \
# count                                             149790        149790
# unique                                               917            21
# top     New York-Newark-Jersey City, NY-NJ-PA Metro Area            --
# freq                                                 187          8253
#
#        NAICS DESCRIPTION ENTERPRISE EMPLOYMENT SIZE NUMBER OF FIRMS  \
# count             149790                     149790          149790
# unique                21                          9            4590
# top                Total                 01:  Total               1
# freq                8253                      18969           13325
#
#        NUMBER OF ESTABLISHMENTS EMPLOYMENT EMPLOYMENT RANGE FLAG  \
# count                    149790     149790                 25379
# unique                     4891      15496                    10
# top                           1          0                     A
# ...

# %%
pd.unique(data['NAICS DESCRIPTION'])
# Out:
# array(['Total', 'Agriculture, Forestry, Fishing and Hunting',
#        'Mining, Quarrying, and Oil and Gas Extraction', 'Utilities',
#        'Construction', 'Manufacturing', 'Wholesale Trade', 'Retail Trade',
#        'Transportation and Warehousing', 'Information',
#        'Finance and Insurance', 'Real Estate and Rental and Leasing',
#        'Professional, Scientific, and Technical Services',
#        'Management of Companies and Enterprises',
#        'Administrative and Support and Waste Management and Remediation Services',
#        'Educational Services', 'Health Care and Social Assistance',
#        'Arts, Entertainment, and Recreation',
#        'Accommodation and Food Services',
#        'Other Services (except Public Administration)',
#        'Industries not classified'], dtype=object)

# %%
data['NUMBER OF FIRMS'].value_counts()
# Out:
# 1         13325
# 2          9539
# 3          7293
# 4          6146
# 5          5222
#           ...
# 4,181         1
# 3,698         1
# 3,433         1
# 7,401         1
# 17,147        1
# Name: NUMBER OF FIRMS, Length: 4590, dtype: int64

# %%
data['NUMBER OF ESTABLISHMENTS'].value_counts()
# Out:
# 1         12415
# 2          8874
# 3          6801
# 4          5781
# 5          4932
#           ...
# 6,005         1
# 3,610         1
# 46,015        1
# 1,877         1
# 10,008        1
# Name: NUMBER OF ESTABLISHMENTS, Length: 4891, dtype: int64

# %%
data.sort_values(by='ENTERPRISE EMPLOYMENT SIZE', ascending=False).head()
# Out:
#         FIPS    CODE                      MSA DESCRIPTION NAICS   CODE   \
# 80375          31300             Lumberton, NC Micro Area            52
# 139316         46660              Valdosta, GA Metro Area            72
# 15031          14010           Bloomington, IL Metro Area            11
# 123666         42680  Sebastian-Vero Beach, FL Metro Area            --
# 104640         37420                 Pampa, TX Micro Area            54
#
#                                        NAICS DESCRIPTION  \
# 80375                              Finance and Insurance
# 139316                   Accommodation and Food Services
# 15031         Agriculture, Forestry, Fishing and Hunting
# 123666                                             Total
# 104640  Professional, Scientific, and Technical Services
#
#        ENTERPRISE EMPLOYMENT SIZE NUMBER OF FIRMS NUMBER OF ESTABLISHMENTS  \
# 80375                   09:  500+              17                       42
# ...

# %%
data.sort_values(by=['ENTERPRISE EMPLOYMENT SIZE', 'ANNUAL PAYROLL ($1,000)'],
        ascending=[False, False]).head()
# Out:
#         FIPS    CODE                                    MSA DESCRIPTION  \
# 24279          16540             Chambersburg-Waynesboro, PA Metro Area
# 59052          25760                  Helena-West Helena, AR Micro Area
# 59058          25760                  Helena-West Helena, AR Micro Area
# 143298         47900  Washington-Arlington-Alexandria, DC-VA-MD-WV M...
# 36185          19700                              Deming, NM Micro Area
#
#        NAICS   CODE                NAICS DESCRIPTION  \
# 24279             --                           Total
# 59052          48-49  Transportation and Warehousing
# 59058             51                     Information
# 143298            22                       Utilities
# 36185             52           Finance and Insurance
#
#        ENTERPRISE EMPLOYMENT SIZE NUMBER OF FIRMS NUMBER OF ESTABLISHMENTS  \
# 24279                   09:  500+             288                      581
# ...

# %%
data['ANNUAL PAYROLL ($1,000)'] = data['ANNUAL PAYROLL ($1,000)'].apply(lambda x: x.replace(',', '')).astype('int64')
data['ANNUAL PAYROLL ($1,000)'].mean()
# Out:
# 204077.9156552507

# %%
data[data['ANNUAL PAYROLL ($1,000)'] > 204077]['EMPLOYMENT'].apply(lambda x: x.replace(',', '')).astype('int64').mean()
# Out:
# 40319.524065368256

# %%
data.groupby(['NAICS DESCRIPTION'])[['EMPLOYMENT']].describe(percentiles=[])
# Out:
#                                                    EMPLOYMENT                \
#                                                         count unique    top
# NAICS DESCRIPTION
# Accommodation and Food Services                          8236   3546      0
# Administrative and Support and Waste Management...       7852   2448      0
# Agriculture, Forestry, Fishing and Hunting               5175    442      0
# Arts, Entertainment, and Recreation                      7024   1563      0
# Construction                                             7649   2683      0
# Educational Services                                     6792   1563      0
# Finance and Insurance                                    8121   2002      0
# Health Care and Social Assistance                        8247   3889      0
# Industries not classified                                3576    158      0
# Information                                              7357   1409      0
# ...
